# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hamid\Desktop\git_project\Notebooks

# %%
os.listdir()
# Out:
# ['.ipynb',
#  'data_analiysis.ipynb',
#  'data_loading.ipynb',
#  'data_preprocessing.ipynb',
#  'feature_creation.ipynb',
#  'ReadMe.md']

# %%
os.listdir("..")
# Out:
# ['.git',
#  '.gitignore',
#  '.vscode',
#  'Data',
#  'errors',
#  'log',
#  'models',
#  'Notebooks',
#  'pipline',
#  'ReadMe.md',
#  'requirements.txt',
#  'results',
#  'scripts',
#  'src',
#  'test']

# %%
import pandas as pd

# load data
df = pd.read_csv("../Data/Raw_Data/Global football events and player performance.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 314.8+ KB

# %%
df['FTR'].value_counts()
# Out:
# FTR
# H    175
# A    123
# D     82
# Name: count, dtype: int64

# %%
for col in df.select_dtypes(include='object').columns:
    print(col, df[col].unique())
# Out:
# Div ['E0']
# Date ['11/08/2023' '12/08/2023' '13/08/2023' '14/08/2023' '18/08/2023'
#  '19/08/2023' '20/08/2023' '21/08/2023' '25/08/2023' '26/08/2023'
#  '27/08/2023' '01/09/2023' '02/09/2023' '03/09/2023' '16/09/2023'
#  '17/09/2023' '18/09/2023' '23/09/2023' '24/09/2023' '30/09/2023'
#  '01/10/2023' '02/10/2023' '03/10/2023' '07/10/2023' '08/10/2023'
#  '21/10/2023' '22/10/2023' '23/10/2023' '27/10/2023' '28/10/2023'
#  '29/10/2023' '04/11/2023' '05/11/2023' '06/11/2023' '11/11/2023'
#  '12/11/2023' '25/11/2023' '26/11/2023' '27/11/2023' '02/12/2023'
#  '03/12/2023' '05/12/2023' '06/12/2023' '07/12/2023' '09/12/2023'
#  '10/12/2023' '15/12/2023' '16/12/2023' '17/12/2023' '21/12/2023'
#  '22/12/2023' '23/12/2023' '24/12/2023' '26/12/2023' '27/12/2023'
#  '28/12/2023' '30/12/2023' '31/12/2023' '01/01/2024' '02/01/2024'
#  '12/01/2024' '13/01/2024' '14/01/2024' '20/01/2024' '21/01/2024'
#  '22/01/2024' '30/01/2024' '31/01/2024' '01/02/2024' '03/02/2024'
# ...

# %%
df['FTR'].unique()
# Out:
# array(['A', 'H', 'D'], dtype=object)

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 314.8+ KB
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.800000    1.478947    0.734211    0.626316   15.402632   12.181579
# std      1.365616    1.277811    0.831687    0.823367    6.261959    5.467696
# min      0.000000    0.000000    0.000000    0.000000    1.000000    2.000000
# 25%      1.000000    1.000000    0.000000    0.000000   11.000000    8.000000
# 50%      2.000000    1.000000    1.000000    0.000000   15.000000   11.000000
# 75%      3.000000    2.000000    1.000000    1.000000   19.000000   15.000000
# max      6.000000    8.000000    4.000000    5.000000   36.000000   30.000000
#
#               HST         AST          HF          AF  ...    AvgC<2.5  \
# ...
