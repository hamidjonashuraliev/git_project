# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hamid\Desktop\git_project\Notebooks

# %%
os.listdir()
# Out:
# ['.ipynb',
#  'data_analiysis.ipynb',
#  'data_loading.ipynb',
#  'data_preprocessing.ipynb',
#  'feature_creation.ipynb',
#  'ReadMe.md']

# %%
os.listdir("..")
# Out:
# ['.git',
#  '.gitignore',
#  'Data',
#  'errors',
#  'log',
#  'models',
#  'Notebooks',
#  'pipline',
#  'ReadMe.md',
#  'requirements.txt',
#  'results',
#  'scripts',
#  'src',
#  'test']

# %%
import pandas as pd

# load data
df = pd.read_csv("../Data/Raw_Data/Global football events and player performance.csv")
