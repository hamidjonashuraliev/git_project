# %%
# Notebook da tekshiring
import pandas as pd
import os

path = r"C:\Users\hamid\Desktop\git_project\Data\Raw_Data\all_stocks.csv"
df = pd.read_csv(path)

print(df["Ticker"].unique())   # ← barcha kompaniyalar
print(df.shape)                # ← qatorlar soni
# Out:
# ['AAPL' 'TSLA' 'MSFT' 'GOOGL' 'AMZN' 'META' 'NVDA' 'NFLX' 'INTC' 'AMD'
#  'TSM' 'BABA']
# (3012, 10)

# %%
import sys
import os

notebook_dir = os.path.abspath("")
BASE_DIR = os.path.dirname(notebook_dir)
sys.path.append(os.path.join(BASE_DIR, "scripts"))

from data_load import load_data

# ✅ Ishlayaptimi tekshiring
df = load_data()
print(df.head(10))
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2025-06-06 00:00:00-04:00  202.197834  204.887162  201.251591  203.114197
# 1  2025-06-09 00:00:00-04:00  203.582346  205.185985  199.229619  200.653961
# 2  2025-06-10 00:00:00-04:00  199.807343  203.542525  199.777463  201.869156
# 3  2025-06-11 00:00:00-04:00  202.695872  203.691921  197.625989  197.994522
# 4  2025-06-12 00:00:00-04:00  198.293336  198.890956  196.580131  198.412857
# 5  2025-06-13 00:00:00-04:00  198.940744  199.578214  194.926670  195.673706
# 6  2025-06-16 00:00:00-04:00  196.520356  197.904863  195.783275  197.635925
# 7  2025-06-17 00:00:00-04:00  196.420746  197.606046  194.438619  194.866913
# 8  2025-06-18 00:00:00-04:00  195.165737  196.789301  194.299180  195.803207
# 9  2025-06-20 00:00:00-04:00  197.456661  200.902980  196.082109  200.205750
#
#      Volume  Dividends  Stock Splits Ticker Currency
# 0  46607700        0.0           0.0   AAPL      USD
# ...

# %%
# 2️⃣ CELL - datani yuklash
df = load_data()

# %%
# 3️⃣ CELL - tekshirish
df.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2025-06-06 00:00:00-04:00  202.197834  204.887162  201.251591  203.114197
# 1  2025-06-09 00:00:00-04:00  203.582346  205.185985  199.229619  200.653961
# 2  2025-06-10 00:00:00-04:00  199.807343  203.542525  199.777463  201.869156
# 3  2025-06-11 00:00:00-04:00  202.695872  203.691921  197.625989  197.994522
# 4  2025-06-12 00:00:00-04:00  198.293336  198.890956  196.580131  198.412857
#
#      Volume  Dividends  Stock Splits Ticker Currency
# 0  46607700        0.0           0.0   AAPL      USD
# 1  72862600        0.0           0.0   AAPL      USD
# 2  54672600        0.0           0.0   AAPL      USD
# 3  60989900        0.0           0.0   AAPL      USD
# 4  43904600        0.0           0.0   AAPL      USD

# %%
# 4️⃣ CELL - ma'lumot haqida
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012 entries, 0 to 3011
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3012 non-null   object
#  1   Open          3012 non-null   float64
#  2   High          3012 non-null   float64
#  3   Low           3012 non-null   float64
#  4   Close         3012 non-null   float64
#  5   Volume        3012 non-null   int64
#  6   Dividends     3012 non-null   float64
#  7   Stock Splits  3012 non-null   float64
#  8   Ticker        3012 non-null   object
#  9   Currency      3012 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 235.4+ KB

# %%
# 5️⃣ CELL - statistika
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3012.000000  3012.000000  3012.000000  3012.000000  3.012000e+03
# mean    275.457624   279.034062   271.686249   275.440983  5.423722e+07
# std     170.807281   172.570176   168.673761   170.603516  5.289156e+07
# min      19.500000    19.549999    18.969999    19.309999  2.753900e+06
# 25%     160.102497   162.367500   157.659996   160.327503  1.911748e+07
# 50%     232.925003   235.495767   230.159377   232.782745  3.730995e+07
# 75%     370.267509   374.007622   365.212583   370.525002  6.462768e+07
# max     789.296390   794.384398   778.990557   788.148987  5.239080e+08
#
#          Dividends  Stock Splits
# count  3012.000000    3012.00000
# mean      0.004393       0.00332
# std       0.062143       0.18221
# min       0.000000       0.00000
# 25%       0.000000       0.00000
# 50%       0.000000       0.00000
# 75%       0.000000       0.00000
# max       2.000000      10.00000

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hamid\Desktop\git_project\Notebooks

# %%
os.listdir()
# Out:
# ['.ipynb',
#  'data_analysis.ipynb',
#  'data_loading.ipynb',
#  'data_preprocessing.ipynb',
#  'feature_creation.ipynb',
#  'ReadMe.md']

# %%
os.listdir("..")
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  '.vscode',
#  'Data',
#  'errors',
#  'log',
#  'models',
#  'myenv',
#  'Notebooks',
#  'pipline',
#  'ReadMe.md',
#  'requirements.txt',
#  'results',
#  'scripts',
#  'src',
#  'src__init__.py',
#  'test',
#  'test_env']

# %%
import pandas as pd

# load data
df = pd.read_csv("../Data/Raw_Data/all_stocks.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012 entries, 0 to 3011
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3012 non-null   object
#  1   Open          3012 non-null   float64
#  2   High          3012 non-null   float64
#  3   Low           3012 non-null   float64
#  4   Close         3012 non-null   float64
#  5   Volume        3012 non-null   int64
#  6   Dividends     3012 non-null   float64
#  7   Stock Splits  3012 non-null   float64
#  8   Ticker        3012 non-null   object
#  9   Currency      3012 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 235.4+ KB

# %%
df['Close'].value_counts()
# Out:
# Close
# 222.690002    3
# 44.060001     3
# 232.380005    2
# 329.649994    2
# 237.208923    2
#              ..
# 229.002136    1
# 232.671753    1
# 232.123306    1
# 230.936661    1
# 203.114197    1
# Name: count, Length: 2961, dtype: int64

# %%
for col in df.select_dtypes(include='object').columns:
    print(col, df[col].unique())
# Out:
# Date ['2025-06-06 00:00:00-04:00' '2025-06-09 00:00:00-04:00'
#  '2025-06-10 00:00:00-04:00' '2025-06-11 00:00:00-04:00'
#  '2025-06-12 00:00:00-04:00' '2025-06-13 00:00:00-04:00'
#  '2025-06-16 00:00:00-04:00' '2025-06-17 00:00:00-04:00'
#  '2025-06-18 00:00:00-04:00' '2025-06-20 00:00:00-04:00'
#  '2025-06-23 00:00:00-04:00' '2025-06-24 00:00:00-04:00'
#  '2025-06-25 00:00:00-04:00' '2025-06-26 00:00:00-04:00'
#  '2025-06-27 00:00:00-04:00' '2025-06-30 00:00:00-04:00'
#  '2025-07-01 00:00:00-04:00' '2025-07-02 00:00:00-04:00'
#  '2025-07-03 00:00:00-04:00' '2025-07-07 00:00:00-04:00'
#  '2025-07-08 00:00:00-04:00' '2025-07-09 00:00:00-04:00'
#  '2025-07-10 00:00:00-04:00' '2025-07-11 00:00:00-04:00'
#  '2025-07-14 00:00:00-04:00' '2025-07-15 00:00:00-04:00'
#  '2025-07-16 00:00:00-04:00' '2025-07-17 00:00:00-04:00'
#  '2025-07-18 00:00:00-04:00' '2025-07-21 00:00:00-04:00'
#  '2025-07-22 00:00:00-04:00' '2025-07-23 00:00:00-04:00'
# ...

# %%
df['Close'].unique()
# Out:
# array([203.11419678, 200.65396118, 201.86915588, ..., 127.20999908,
#        125.94999695, 121.05999756], shape=(2961,))

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012 entries, 0 to 3011
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3012 non-null   object
#  1   Open          3012 non-null   float64
#  2   High          3012 non-null   float64
#  3   Low           3012 non-null   float64
#  4   Close         3012 non-null   float64
#  5   Volume        3012 non-null   int64
#  6   Dividends     3012 non-null   float64
#  7   Stock Splits  3012 non-null   float64
#  8   Ticker        3012 non-null   object
#  9   Currency      3012 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 235.4+ KB
#               Open         High          Low        Close        Volume  \
# count  3012.000000  3012.000000  3012.000000  3012.000000  3.012000e+03
# mean    275.457624   279.034062   271.686249   275.440983  5.423722e+07
# ...
