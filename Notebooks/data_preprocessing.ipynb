# %%
import pandas as pd

df = pd.read_csv("../Data/Preprocessed_Data/clean_data.csv")
df.head()
# Out:
#    Div      Date      Time  HomeTeam  AwayTeam      FTHG   FTAG  FTR  HTHG  \
# 0  0.0  0.361345  0.928571  0.263158  0.631579  0.000000  0.375    0  0.00
# 1  0.0  0.403361  0.000000  0.000000  0.789474  0.333333  0.125    2  0.50
# 2  0.0  0.403361  0.285714  0.105263  0.947368  0.166667  0.125    1  0.00
# 3  0.0  0.403361  0.285714  0.210526  0.578947  0.666667  0.125    2  0.25
# 4  0.0  0.403361  0.285714  0.421053  0.473684  0.000000  0.125    0  0.00
#
#    HTAG  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA     PCAHH     PCAHA  \
# 0   0.4  ...  0.206044  0.90  0.586957  0.595238  0.500000  0.422222
# 1   0.0  ...  0.302198  0.20  0.586957  0.595238  0.454545  0.422222
# 2   0.0  ...  0.162088  0.60  0.739130  0.428571  0.636364  0.311111
# 3   0.0  ...  0.260989  0.25  0.717391  0.452381  0.613636  0.288889
# 4   0.0  ...  0.049451  0.55  0.826087  0.333333  0.704545  0.222222
#
#     MaxCAHH   MaxCAHA   AvgCAHH   AvgCAHA
# 0  0.411719  0.423942  0.444444  0.513514
# ...

# %%
df.info()
df.isnull().sum()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(105), int64(1)
# memory usage: 314.8 KB
# (380, 106)
