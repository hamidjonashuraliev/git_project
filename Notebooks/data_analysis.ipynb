# %%
import pandas as pd

df = pd.read_csv("../Data/Raw_Data/all_stocks.csv")
df.head()

df.shape
df.columns
df.info()
df.describe()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3012 entries, 0 to 3011
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3012 non-null   object
#  1   Open          3012 non-null   float64
#  2   High          3012 non-null   float64
#  3   Low           3012 non-null   float64
#  4   Close         3012 non-null   float64
#  5   Volume        3012 non-null   int64
#  6   Dividends     3012 non-null   float64
#  7   Stock Splits  3012 non-null   float64
#  8   Ticker        3012 non-null   object
#  9   Currency      3012 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 235.4+ KB
#                            Date        Open        High         Low  \
# 3007  2026-06-01 00:00:00-04:00  124.199997  126.349998  123.989998
# 3008  2026-06-02 00:00:00-04:00  132.250000  134.089996  130.520004
# 3009  2026-06-03 00:00:00-04:00  128.759995  128.889999  126.830002
# ...

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Ticker          0
# Currency        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker', 'Currency'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Close', data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Close', data=df)
plt.show()

# %%
df['Close'].value_counts(normalize=True) * 100
# Out:
# Close
# 222.690002    0.099602
# 44.060001     0.099602
# 232.380005    0.066401
# 329.649994    0.066401
# 237.208923    0.066401
#                 ...
# 229.002136    0.033201
# 232.671753    0.033201
# 232.123306    0.033201
# 230.936661    0.033201
# 203.114197    0.033201
# Name: proportion, Length: 2961, dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits', 'Ticker', 'Currency'],
#       dtype='object')

# %%
sns.histplot(df['Open'])
plt.show()

# %%
sns.countplot(x='Ticker', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=False)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df_num = df.select_dtypes(include=['int64', 'float64'])

sns.heatmap(df_num.corr(), annot=True)
plt.show()

# %%
sns.boxplot(data=df[['Dividends','Stock Splits']])
# Out:
# <Axes: >

# %%
sns.boxplot(x='Ticker', y='Dividends', data=df)
# Out:
# <Axes: xlabel='Ticker', ylabel='Dividends'>
